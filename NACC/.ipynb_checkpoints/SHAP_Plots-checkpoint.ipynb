# %% [markdown]
# Utilizing this nice tool for Visualization of impact of features for classification
# https://github.com/slundberg/shap

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from scipy import interp
import numpy as np
import pandas as pd
from itertools import cycle
from sklearn.ensemble import (RandomForestClassifier,
                              GradientBoostingClassifier)
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import resample
from sklearn.utils import shuffle
from sklearn.preprocessing import label_binarize
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import os
import shap

# %%
data_path = '/Users/subashkhanal/Desktop/Lin_Lab/LinBrainLab/MLforMedicine/NACC/data/'
df_mri_dx = pd.read_csv(os.path.join(data_path,'lin10232020mri_diag.csv'))
df_partial = df_mri_dx.loc[:,'NACCICV':'RHIPPO']
df_partial['NACCUDSD'] = df_mri_dx['NACCUDSD']
df_full = df_mri_dx.loc[:,'NACCICV':'RTRTEMM']
df_full['NACCUDSD'] = df_mri_dx['NACCUDSD']
portion = 'full'
if portion == 'full':
    
    df = df_full  
else:
    df = df_partial #experiment with 15 features realted to TOTAL volumes
cols = df.columns[:-1]

# %%
df_CN=df[df.NACCUDSD==1] #Normal = 1950
df_EMCI=df[df.NACCUDSD==2]# nMCI = 542
df_LMCI=df[df.NACCUDSD==3]#MCI = 564
df_AD=df[df.NACCUDSD==4]#AD = 950
print(len(df_CN),len(df_EMCI),len(df_LMCI),len(df_AD))
# Out:
# 1950 542 564 950

# %%
df_sampled=pd.concat([df_CN, df_AD])
df_sampled=shuffle(df_sampled)
y=df_sampled.NACCUDSD
X=df_sampled.drop('NACCUDSD',axis=1)
X_1=df_sampled.drop('NACCUDSD',axis=1)

# %%
y = label_binarize(y, classes=[1, 4])
numFeature=X.shape[1]
y=y.ravel()
scaler = StandardScaler()
scaler.fit(X)
X=scaler.transform(X)

# %%
shap.initjs()
clf=RandomForestClassifier(n_estimators=100,criterion='gini',class_weight='balanced')
clf.fit(X, y).predict_proba(X) 
model = clf
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)
fig = shap.summary_plot(shap_values, pd.DataFrame(X,columns=cols),show=False)
#plt.savefig('SHAP_full.png')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
import shap
shap.initjs()
clf = GradientBoostingClassifier(n_estimators=100)
clf.fit(X, y).predict_proba(X) 
model = clf
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)
fig = shap.summary_plot(shap_values, pd.DataFrame(X,columns=cols),show=False)
#plt.savefig('SHAP_full.png')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop

# %%
data = X
target = y #np.array([x-4 if x==4.0 else 1 for x in y])
#target=keras.utils.to_categorical(target,2)

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2)
model = Sequential()
model.add(Dense(512,activation="tanh",input_shape=(numFeature,)))
model.add(Dense(64,activation="tanh"))
model.add(Dropout(0.4))
model.add(Dense(64,activation="tanh"))
model.add(Dropout(0.4))
model.add(Dense(64,activation="tanh"))
model.add(Dropout(0.4))
model.add(Dense(16,activation="relu"))
model.add(Dense(2,activation="softmax"))
model.compile(loss="binary_crossentropy",optimizer='Adam',metrics=['accuracy'])
model.fit(x_train,y_train, batch_size=32, epochs=10, validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 71/71 [==============================] - 0s 3ms/step - loss: 0.7449 - accuracy: 0.4806 - val_loss: 0.7076 - val_accuracy: 0.7266
# Epoch 2/10
# 71/71 [==============================] - 0s 1ms/step - loss: 0.7138 - accuracy: 0.5053 - val_loss: 0.6955 - val_accuracy: 0.6755
# Epoch 3/10
# 71/71 [==============================] - 0s 1ms/step - loss: 0.7054 - accuracy: 0.4881 - val_loss: 0.6947 - val_accuracy: 0.6314
# Epoch 4/10
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7006 - accuracy: 0.5207 - val_loss: 0.6949 - val_accuracy: 0.7690
# Epoch 5/10
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6987 - accuracy: 0.5062 - val_loss: 0.6941 - val_accuracy: 0.7496
# Epoch 6/10
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6968 - accuracy: 0.5199 - val_loss: 0.6939 - val_accuracy: 0.7584
# Epoch 7/10
# ...

# %%
y_pred = model.predict(x_test).argmax(axis=-1)
accuracy_score(y_test, y_pred)
# Out:
# 0.7213403880070547

# %%
def f(X_sam):
    return model.predict(X_sam)

# %%
X_sample = shap.sample(X, 100)
explainer = shap.KernelExplainer(f, X_sample)
shap_values = explainer.shap_values(X_sample)
fig = shap.summary_plot(shap_values, pd.DataFrame(X_sample,columns=cols),show=False)
